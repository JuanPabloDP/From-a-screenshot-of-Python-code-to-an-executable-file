# %%
import cv2
import pytesseract
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pytesseract import Output
pytesseract.pytesseract.tesseract_cmd = r"..\source\Tesseract-OCR\tesseract.exe"

code = cv2.imread("..\data\codpy.png")


plt.imshow(code)

# %%
if code is None:
    raise ValueError("La imagen no se cargó. Revisa la ruta del archivo.")
else:
    print("Todo bien")
# Out:
# Todo bien

# %%
list_result = pytesseract.image_to_string(code)
print(list_result)
# Out:
# class Animal:
# def sonido(self):
# return "Sonido genérico"
#
# class Perro(Animal):
# def sonido(self):
# return "Guau"
#
# mi_perro = Perro()
# print(mi_perro.sonido()) # Resultado: Guau

# %%
data = pytesseract.image_to_data(code, output_type=pytesseract.Output.DATAFRAME)
data_ = data.dropna().reset_index(drop=True)
data_ = data[data["word_num"] == 1]

# %%
counts, bins, _ = plt.hist(data_["left"])

clases = []
count = 0
for i in range(len(bins)-1):
    if counts[i] > 0:
        print(f"Indentacion {count}: {bins[i]:.2f} a {bins[i+1]:.2f}, elementos = {counts[i]}")
        count += 1
        clases.append((bins[i], bins[i+1]))
# Out:
# Indentacion 0: 30.00 a 43.90, elementos = 4.0
# Indentacion 1: 85.60 a 99.50, elementos = 2.0
# Indentacion 2: 155.10 a 169.00, elementos = 2.0

# %%
data
# Out:
#     level  page_num  block_num  par_num  line_num  word_num  left  top  width  \
# 0       1         1          0        0         0         0     0    0   1464
# 1       2         1          1        0         0         0    34   44    530
# 2       3         1          1        1         0         0    34   44    530
# 3       4         1          1        1         1         0    34   44    210
# 4       5         1          1        1         1         1    34   44     79
# 5       5         1          1        1         1         2   134   44    110
# 6       4         1          1        1         2         0    98   90    279
# 7       5         1          1        1         2         1    98   92     47
# 8       5         1          1        1         2         2   167   90    210
# 9       4         1          1        1         3         0   169  139    395
# 10      5         1          1        1         3         1   169  141     94
# 11      5         1          1        1         3         2   285  140    113
# 12      5         1          1        1         3         3   419  139    145
# 13      2         1          2        0         0         0    32  234    347
# 14      3         1          2        1         0         0    32  234    347
# 15      4         1          2        1         1         0    32  234    328
# 16      5         1          2        1         1         1    32  236     79
# 17      5         1          2        1         1         2   133  234    227
# 18      4         1          2        1         2         0    98  282    279
# 19      5         1          2        1         2         1    98  284     47
# 20      5         1          2        1         2         2   167  282    210
# 21      4         1          2        1         3         0   169  332    210
# 22      5         1          2        1         3         1   169  333     94
# 23      5         1          2        1         3         2   285  332     94
# 24      2         1          3        0         0         0    30  426    721
# 25      3         1          3        1         0         0    30  426    721
# 26      4         1          3        1         1         0    30  426    297
# 27      5         1          3        1         1         1    30  428    132
# 28      5         1          3        1         1         2   182  436     15
# 29      5         1          3        1         1         3   217  426    110
# 30      4         1          3        1         2         0    32  474    719
# 31      5         1          3        1         2         1    32  474    396
# 32      5         1          3        1         2         2   467  477     17
# 33      5         1          3        1         2         3   503  476    160
# 34      5         1          3        1         2         4   688  476     63
#
#     height       conf                      text
# 0      538  -1.000000                       NaN
# 1      123  -1.000000                       NaN
# 2      123  -1.000000                       NaN
# 3       21  -1.000000                       NaN
# 4       21  96.297958                     class
# 5       21  95.276741                   Animal:
# 6       25  -1.000000                       NaN
# 7       21  93.142075                       def
# 8       25  92.047737             sonido(self):
# 9       28  -1.000000                       NaN
# 10      20  96.057549                    return
# 11      21  92.840347                   "Sonido
# 12      28  90.054985                 genérico"
# 13     119  -1.000000                       NaN
# 14     119  -1.000000                       NaN
# 15      25  -1.000000                       NaN
# 16      21  92.498260                     class
# 17      25  91.227928            Perro(Animal):
# 18      25  -1.000000                       NaN
# 19      21  93.249992                       def
# 20      25  90.922119             sonido(self):
# 21      21  -1.000000                       NaN
# 22      20  91.277412                    return
# 23      21  84.463539                    "Guau"
# 24      77  -1.000000                       NaN
# 25      77  -1.000000                       NaN
# 26      29  -1.000000                       NaN
# 27      27  92.531372                  mi_perro
# 28       9  93.298553                         =
# 29      25  92.738899                   Perro()
# 30      29  -1.000000                       NaN
# 31      29  91.717865  print(mi_perro.sonido())
# 32      20  91.717865                         #
# 33      21  91.716492                Resultado:
# 34      21  91.716492                      Guau

# %%
# Limpiar nulos o vacíos en texto
data = data.dropna(subset=['text'])
data = data[data['text'].str.strip() != '']

# Agrupar por los identificadores de línea
lines = (data
    .sort_values(['block_num', 'par_num', 'line_num', 'left'])  # mantener orden visual
    .groupby(['page_num', 'block_num', 'par_num', 'line_num'], as_index=False)
    .agg({
        'left': 'min',                    # tomar el left más bajo (primera palabra)
        'text': lambda x: ' '.join(x)     # concatenar las palabras
    })
)

lines.head(100)
# Out:
#    page_num  block_num  par_num  line_num  left  \
# 0         1          1        1         1    34
# 1         1          1        1         2    98
# 2         1          1        1         3   169
# 3         1          2        1         1    32
# 4         1          2        1         2    98
# 5         1          2        1         3   169
# 6         1          3        1         1    30
# 7         1          3        1         2    32
#
#                                          text
# 0                               class Animal:
# 1                           def sonido(self):
# 2                    return "Sonido genérico"
# 3                        class Perro(Animal):
# 4                           def sonido(self):
# 5                               return "Guau"
# 6                          mi_perro = Perro()
# 7  print(mi_perro.sonido()) # Resultado: Guau

# %%
print("jsjsjs\n" + "    " + "aaaa")
# Out:
# jsjsjs
#     aaaa

# %%
counts, bins, _ = plt.hist(lines["left"])
plt.close()

clases = []
for i in range(len(bins)-1):
    if counts[i] > 0:
        clases.append((bins[i], bins[i+1]))

def obtener_indentacion(numero):
    for i, (start, end) in enumerate(clases):
        if start <= numero < end:
            return i
    return len(clases) - 1  # si no entra en ningún intervalo, asignar al último

lines["Indentacion"] = lines["left"].apply(obtener_indentacion)

# %%
lines
# Out:
#    page_num  block_num  par_num  line_num  left  \
# 0         1          1        1         1    34
# 1         1          1        1         2    98
# 2         1          1        1         3   169
# 3         1          2        1         1    32
# 4         1          2        1         2    98
# 5         1          2        1         3   169
# 6         1          3        1         1    30
# 7         1          3        1         2    32
#
#                                          text  Indentacion
# 0                               class Animal:            0
# 1                           def sonido(self):            1
# 2                    return "Sonido genérico"            2
# 3                        class Perro(Animal):            0
# 4                           def sonido(self):            1
# 5                               return "Guau"            2
# 6                          mi_perro = Perro()            0
# 7  print(mi_perro.sonido()) # Resultado: Guau            0

# %%
string = ""

for i in range(len(lines)):
    if lines.iloc[i]["line_num"] == 1:
        aux = "\n"
    else:
        aux = ""
    aux += lines.iloc[i]["Indentacion"] * "\t" + lines.iloc[i]["text"] + "\n"
    string += aux

print(string)
# Out:
# class Animal:
# 	def sonido(self):
# 		return "Sonido genérico"
#
# class Perro(Animal):
# 	def sonido(self):
# 		return "Guau"
#
# mi_perro = Perro()
# print(mi_perro.sonido()) # Resultado: Guau
