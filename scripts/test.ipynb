# %% [markdown]
# # From a Screenshot of Python Code to an Executable File

# %%
from codeScreenshot import screenshot_to_code

# %% [markdown]
# ## Image 1

# %%
screenshot_to_code("..\data\clase_animal.png","result1")
# Out:
# Guau

# %%
screenshot_to_code("..\data\\frutas.png","result2")
# Out:
# manzana
# banana
# uva

# %%
screenshot_to_code("..\data\\for_sencillo.png","result3")
# Out:
# 1
# 2
# 3
# 4
# 5
