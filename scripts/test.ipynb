# %% [markdown]
# # From a Screenshot of Python Code to an Executable File

# %%
from codeScreenshot import screenshot_to_code

# %% [markdown]
# ## Image 1

# %%
screenshot_to_code("..\data\codifo.png","result1")
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\User\anaconda3\envs\defecto\Lib\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[4], line 1
#     screenshot_to_code("..\data\codifo.png","result1")
#
#   File c:\Users\User\Desktop\From-a-screenshot-of-Python-code-to-an-executable-file\scripts\codeScreenshot.py:79 in screenshot_to_code
#     if lines.iloc[i]["line_num"] == 1:
#
#   File c:\Users\User\Desktop\From-a-screenshot-of-Python-code-to-an-executable-file\scripts\stringToScript.py:9 in string_to_script
#     exec(code)
#
#   File <string>:10
#     print('MuLtipLle:*,a*b)
#           ^
# SyntaxError: unterminated string literal (detected at line 10)
